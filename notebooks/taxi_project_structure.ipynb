# %%
# %sql

CREATE CATALOG IF NOT EXISTS "taxi_trips";

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS taxi_trips.bronze
COMMENT 'Camada Bronze para armazenamento de dados brutos';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS taxi_trips.silver
COMMENT 'Camada silver para armazenamento de dados tratados';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS taxi_trips.gold
COMMENT 'Camada gold para armazenamento do modelo relacional';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS taxi_trips.bronze.raw;

# %%
# %sql
CREATE VOLUME iF NOT EXISTS taxi_trips.bronze.bronze
